# %% [markdown]
# # DyMat Demo

# %%
import sys
import json
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
#%matplotlib notebook 
#%matplotlib qt
#%matplotlib widget
plt.rcParams['figure.constrained_layout.use'] = True

# %%
# for DyMat development
# %load_ext autoreload 
# %autoreload 1
sys.path.insert(0, r'..')
# %aimport DyMat

# %%
# OMEdit default paht to models
#%ls %TEMP%\OpenModelica\OMEdit\

# %%
#data = DyMat.DyMatFile(r"..\test\DoublePendulum_OpenModelica-1.8.mat")
data = DyMat.DyMatFile(r"..\test\DoublePendulum_OpenModelica-1.9.mat")

# %%
data.nameTree().keys()
# Out:
# dict_keys(['revolute1', 'revolute2', 'boxBody1', 'boxBody2', 'damper', 'world'])

# %%
print(json.dumps(data.nameTree(), sort_keys=True, indent=4)[:1500]) # workaround pretty print nested dicts
# Out:
# {
#     "boxBody1": {
#         "I[1,1]": "boxBody1.I[1,1]",
#         "I[1,2]": "boxBody1.I[1,2]",
#         "I[1,3]": "boxBody1.I[1,3]",
#         "I[2,1]": "boxBody1.I[2,1]",
#         "I[2,2]": "boxBody1.I[2,2]",
#         "I[2,3]": "boxBody1.I[2,3]",
#         "I[3,1]": "boxBody1.I[3,1]",
#         "I[3,2]": "boxBody1.I[3,2]",
#         "I[3,3]": "boxBody1.I[3,3]",
#         "R": {
#             "T[1,1]": "boxBody1.R.T[1,1]",
#             "T[1,2]": "boxBody1.R.T[1,2]",
#             "T[1,3]": "boxBody1.R.T[1,3]",
#             "T[2,1]": "boxBody1.R.T[2,1]",
#             "T[2,2]": "boxBody1.R.T[2,2]",
#             "T[2,3]": "boxBody1.R.T[2,3]",
#             "T[3,1]": "boxBody1.R.T[3,1]",
#             "T[3,2]": "boxBody1.R.T[3,2]",
#             "T[3,3]": "boxBody1.R.T[3,3]",
#             "w[1]": "boxBody1.R.w[1]",
#             "w[2]": "boxBody1.R.w[2]",
#             "w[3]": "boxBody1.R.w[3]"
#         },
#         "a_0[1]": "boxBody1.a_0[1]",
#         "a_0[2]": "boxBody1.a_0[2]",
#         "a_0[3]": "boxBody1.a_0[3]",
#         "angles_fixed": "boxBody1.angles_fixed",
#         "angles_start[1]": "boxBody1.angles_start[1]",
#         "angles_start[2]": "boxBody1.angles_start[2]",
#         "angles_start[3]": "boxBody1.angles_start[3]",
#         "animation": "boxBody1.animation",
#         "body": {
#             "I[1,1]": "boxBody1.body.I[1,1]",
#             "I[1,2]": "boxBody1.body.I[1,2]",
#             "I[1,3]": "boxBody1.body.I[1,3]",
#             "I[2,1]": "boxBody1.body.I[2,1]",
#             "I[2,2]": "boxBody1.body.I[2,2]",

# %%
print(json.dumps(data.nameTree(type='parameter')['revolute1'], sort_keys=True, indent=4)) # workaround pretty print nested dicts
# Out:
# {
#     "animation": "revolute1.animation",
#     "cylinder": {
#         "height": "revolute1.cylinder.height",
#         "length": "revolute1.cylinder.length",
#         "lengthDirection[1]": "revolute1.cylinder.lengthDirection[1]",
#         "lengthDirection[2]": "revolute1.cylinder.lengthDirection[2]",
#         "lengthDirection[3]": "revolute1.cylinder.lengthDirection[3]",
#         "specularCoefficient": "revolute1.cylinder.specularCoefficient",
#         "width": "revolute1.cylinder.width"
#     },
#     "cylinderColor[2]": "revolute1.cylinderColor[2]",
#     "cylinderColor[3]": "revolute1.cylinderColor[3]",
#     "cylinderDiameter": "revolute1.cylinderDiameter",
#     "cylinderLength": "revolute1.cylinderLength",
#     "e[1]": "revolute1.e[1]",
#     "e[2]": "revolute1.e[2]",
#     "e[3]": "revolute1.e[3]",
#     "fixed": {
#         "flange": {
#             "phi": "revolute1.fixed.flange.phi"
#         },
#         "phi0": "revolute1.fixed.phi0"
#     },
#     "n[1]": "revolute1.n[1]",
#     "n[2]": "revolute1.n[2]",
#     "n[3]": "revolute1.n[3]",
#     "specularCoefficient": "revolute1.specularCoefficient",
#     "stateSelect": "revolute1.stateSelect",
#     "support": {
#         "phi": "revolute1.support.phi"
#     }
# }

# %%
print(json.dumps(data.nameTree(type='simulation')['revolute1'], sort_keys=True, indent=4)[:5000]) # workaround pretty print nested dicts
# Out:
# {
#     "R_rel": {
#         "T[1,1]": "revolute1.R_rel.T[1,1]",
#         "T[1,2]": "revolute1.R_rel.T[1,2]",
#         "T[1,3]": "revolute1.R_rel.T[1,3]",
#         "T[2,1]": "revolute1.R_rel.T[2,1]",
#         "T[2,2]": "revolute1.R_rel.T[2,2]",
#         "T[2,3]": "revolute1.R_rel.T[2,3]",
#         "T[3,1]": "revolute1.R_rel.T[3,1]",
#         "T[3,2]": "revolute1.R_rel.T[3,2]",
#         "T[3,3]": "revolute1.R_rel.T[3,3]",
#         "w[1]": "revolute1.R_rel.w[1]",
#         "w[1]::der": "der(revolute1.R_rel.w[1])",
#         "w[2]": "revolute1.R_rel.w[2]",
#         "w[2]::der": "der(revolute1.R_rel.w[2])",
#         "w[3]": "revolute1.R_rel.w[3]",
#         "w[3]::der": "der(revolute1.R_rel.w[3])"
#     },
#     "a": "revolute1.a",
#     "angle": "revolute1.angle",
#     "axis": {
#         "phi": "revolute1.axis.phi",
#         "tau": "revolute1.axis.tau"
#     },
#     "cylinder": {
#         "R": {
#             "T[1,1]": "revolute1.cylinder.R.T[1,1]",
#             "T[1,2]": "revolute1.cylinder.R.T[1,2]",
#             "T[1,3]": "revolute1.cylinder.R.T[1,3]",
#             "T[2,1]": "revolute1.cylinder.R.T[2,1]",
#             "T[2,2]": "revolute1.cylinder.R.T[2,2]",
#             "T[2,3]": "revolute1.cylinder.R.T[2,3]",
#             "T[3,1]": "revolute1.cylinder.R.T[3,1]",
#             "T[3,2]": "revolute1.cylinder.R.T[3,2]",
#             "T[3,3]": "revolute1.cylinder.R.T[3,3]",
#             "w[1]": "revolute1.cylinder.R.w[1]",
#             "w[2]": "revolute1.cylinder.R.w[2]",
#             "w[3]": "revolute1.cylinder.R.w[3]"
#         },
#         "color[1]": "revolute1.cylinder.color[1]",
#         "color[2]": "revolute1.cylinder.color[2]",
#         "color[3]": "revolute1.cylinder.color[3]",
#         "extra": "revolute1.cylinder.extra",
#         "r[1]": "revolute1.cylinder.r[1]",
#         "r[2]": "revolute1.cylinder.r[2]",
#         "r[3]": "revolute1.cylinder.r[3]",
#         "r_shape[1]": "revolute1.cylinder.r_shape[1]",
#         "r_shape[2]": "revolute1.cylinder.r_shape[2]",
#         "r_shape[3]": "revolute1.cylinder.r_shape[3]",
#         "widthDirection[1]": "revolute1.cylinder.widthDirection[1]",
#         "widthDirection[2]": "revolute1.cylinder.widthDirection[2]",
#         "widthDirection[3]": "revolute1.cylinder.widthDirection[3]"
#     },
#     "cylinderColor[1]": "revolute1.cylinderColor[1]",
#     "fixed": {
#         "flange": {
#             "tau": "revolute1.fixed.flange.tau"
#         }
#     },
#     "frame_a": {
#         "R": {
#             "T[1,1]": "revolute1.frame_a.R.T[1,1]",
#             "T[1,2]": "revolute1.frame_a.R.T[1,2]",
#             "T[1,3]": "revolute1.frame_a.R.T[1,3]",
#             "T[2,1]": "revolute1.frame_a.R.T[2,1]",
#             "T[2,2]": "revolute1.frame_a.R.T[2,2]",
#             "T[2,3]": "revolute1.frame_a.R.T[2,3]",
#             "T[3,1]": "revolute1.frame_a.R.T[3,1]",
#             "T[3,2]": "revolute1.frame_a.R.T[3,2]",
#             "T[3,3]": "revolute1.frame_a.R.T[3,3]",
#             "w[1]": "revolute1.frame_a.R.w[1]",
#             "w[2]": "revolute1.frame_a.R.w[2]",
#             "w[3]": "revolute1.frame_a.R.w[3]"
#         },
#         "f[1]": "revolute1.frame_a.f[1]",
#         "f[2]": "revolute1.frame_a.f[2]",
#         "f[3]": "revolute1.frame_a.f[3]",
#         "r_0[1]": "revolute1.frame_a.r_0[1]",
#         "r_0[2]": "revolute1.frame_a.r_0[2]",
#         "r_0[3]": "revolute1.frame_a.r_0[3]",
#         "t[1]": "revolute1.frame_a.t[1]",
#         "t[2]": "revolute1.frame_a.t[2]",
#         "t[3]": "revolute1.frame_a.t[3]"
#     },
#     "frame_b": {
#         "R": {
#             "T[1,1]": "revolute1.frame_b.R.T[1,1]",
#             "T[1,2]": "revolute1.frame_b.R.T[1,2]",
#             "T[1,3]": "revolute1.frame_b.R.T[1,3]",
#             "T[2,1]": "revolute1.frame_b.R.T[2,1]",
#             "T[2,2]": "revolute1.frame_b.R.T[2,2]",
#             "T[2,3]": "revolute1.frame_b.R.T[2,3]",
#             "T[3,1]": "revolute1.frame_b.R.T[3,1]",
#             "T[3,2]": "revolute1.frame_b.R.T[3,2]",
#             "T[3,3]": "revolute1.frame_b.R.T[3,3]",
#             "w[1]": "revolute1.frame_b.R.w[1]",
#             "w[2]": "revolute1.frame_b.R.w[2]",
#             "w[3]": "revolute1.frame_b.R.w[3]"
#         },
#         "f[1]": "revolute1.frame_b.f[1]",
#         "f[2]": "revolute1.frame_b.f[2]",
#         "f[3]": "revolute1.frame_b.f[3]",
#         "r_0[1]": "revolute1.frame_b.r_0[1]",
#         "r_0[2]": "revolute1.frame_b.r_0[2]",
#         "r_0[3]": "revolute1.frame_b.r_0[3]",
#         "t[1]": "revolute1.frame_b.t[1]",
#         "t[2]": "revolute1.frame_b.t[2]",
#         "t[3]": "revolute1.frame_b.t[3]"
#     },
#     "internalAxis": {
#         "flange": {
#             "phi": "revolute1.internalAxis.flange.phi",
#             "tau": "revolute1.internalAxis.flange.tau"
#         },
#         "phi": "revolute1.internalAxis.phi",
#         "tau": "revolute1.internalAxis.tau"
#     },
#     "phi": "revolute1.phi",
#     "phi::der": "der(revolute1.phi)",
#     "support": {
#         "tau": "revolute1.support.tau"
#     },
#     "tau": "revolute1.tau",
#     "w": "revolute1.w",
#     "w::der": "der(revolute1.w)"
# }

# %%
#data.names()

# %%
set(data.nameTree().keys())
# Out:
# {'boxBody1', 'boxBody2', 'damper', 'revolute1', 'revolute2', 'world'}

# %%
data.nameTree()['revolute1']['phi']
# Out:
# 'revolute1.phi'

# %%
data['revolute1.phi'][0:0.1]
# Out:
# time
# 0.000    0.000000
# 0.006   -0.000452
# 0.012   -0.001810
# 0.018   -0.004071
# 0.024   -0.007237
# 0.030   -0.011307
# 0.036   -0.016279
# 0.042   -0.022154
# 0.048   -0.028929
# 0.054   -0.036602
# 0.060   -0.045171
# 0.066   -0.054631
# 0.072   -0.064977
# 0.078   -0.076204
# 0.084   -0.088301
# 0.090   -0.101260
# 0.096   -0.115068
# Name: revolute1.phi, dtype: float64

# %%
fix, ax = plt.subplots(1,1)
data['revolute1.phi'].plot(ax=ax)
ax.grid(True)
ax.legend()

data.description('revolute1.phi')
# Out:
# 'Relative rotation angle from frame_a to frame_b [rad]'

# %%
data.get_simulation_data()
# Out:
#        revolute1.phi  revolute1.w  revolute2.phi  revolute2.w  \
# time
# 0.000       0.000000     0.000000       0.000000     0.000000
# 0.006      -0.000452    -0.150817       0.000601     0.200345
# 0.012      -0.001810    -0.301588       0.002404     0.400574
# 0.018      -0.004071    -0.452308       0.005408     0.600668
# 0.024      -0.007237    -0.602962       0.009611     0.800581
# ...              ...          ...            ...          ...
# 2.982      -2.389588     3.856359      -1.730380    -0.599246
# 2.988      -2.366193     3.941289      -1.733473    -0.429552
# 2.994      -2.342304     4.020712      -1.735508    -0.246663
# 3.000      -2.317956     4.093982      -1.736406    -0.050355
# 3.000      -2.317956     4.093982      -1.736406    -0.050355
#
#        der(revolute1.phi)  der(revolute1.w)  der(revolute2.phi)  \
# time
# 0.000            0.000000        -25.139895            0.000000
# 0.006           -0.150817        -25.132452            0.200345
# 0.012           -0.301588        -25.124585            0.400574
# 0.018           -0.452308        -25.115194            0.600668
# 0.024           -0.602962        -25.102455            0.800581
# ...                   ...               ...                 ...
# 2.982            3.856359         14.579600           -0.599246
# 2.988            3.941289         13.713284           -0.429552
# 2.994            4.020712         12.742737           -0.246663
# 3.000            4.093982         11.660966           -0.050355
# 3.000            4.093982         11.660966           -0.050355
#
#        der(revolute2.w)  der(boxBody1.body.w_a[1])  der(boxBody1.body.w_a[2])  \
# time
# 0.000         33.400051                       -0.0                       -0.0
# 0.006         33.381458                       -0.0                       -0.0
# 0.012         33.361427                       -0.0                       -0.0
# 0.018         33.336255                       -0.0                       -0.0
# 0.024         33.299781                       -0.0                       -0.0
# ...                 ...                        ...                        ...
# 2.982         27.196269                        0.0                        0.0
# 2.988         29.375454                        0.0                        0.0
# 2.994         31.593983                        0.0                        0.0
# 3.000         33.847756                        0.0                        0.0
# 3.000         33.847756                        0.0                        0.0
#
#        ...  world.z_label.cylinders[2].specularCoefficient  \
# time   ...
# 0.000  ...                                             0.0
# 0.006  ...                                             0.0
# 0.012  ...                                             0.0
# 0.018  ...                                             0.0
# 0.024  ...                                             0.0
# ...    ...                                             ...
# 2.982  ...                                             0.0
# 2.988  ...                                             0.0
# 2.994  ...                                             0.0
# 3.000  ...                                             0.0
# 3.000  ...                                             0.0
#
#        world.z_label.cylinders[3].specularCoefficient  \
# time
# 0.000                                             0.0
# 0.006                                             0.0
# 0.012                                             0.0
# 0.018                                             0.0
# 0.024                                             0.0
# ...                                               ...
# 2.982                                             0.0
# 2.988                                             0.0
# 2.994                                             0.0
# 3.000                                             0.0
# 3.000                                             0.0
#
#        boxBody1.body.cylinderColor[2]  boxBody1.body.cylinderColor[3]  \
# time
# 0.000                           128.0                           255.0
# 0.006                           128.0                           255.0
# 0.012                           128.0                           255.0
# 0.018                           128.0                           255.0
# 0.024                           128.0                           255.0
# ...                               ...                             ...
# 2.982                           128.0                           255.0
# 2.988                           128.0                           255.0
# 2.994                           128.0                           255.0
# 3.000                           128.0                           255.0
# 3.000                           128.0                           255.0
#
#        boxBody1.frameTranslation.color[2]  boxBody1.frameTranslation.color[3]  \
# time
# 0.000                               128.0                               255.0
# 0.006                               128.0                               255.0
# 0.012                               128.0                               255.0
# 0.018                               128.0                               255.0
# 0.024                               128.0                               255.0
# ...                                   ...                                 ...
# 2.982                               128.0                               255.0
# 2.988                               128.0                               255.0
# 2.994                               128.0                               255.0
# 3.000                               128.0                               255.0
# 3.000                               128.0                               255.0
#
#        boxBody2.body.cylinderColor[2]  boxBody2.body.cylinderColor[3]  \
# time
# 0.000                           128.0                           255.0
# 0.006                           128.0                           255.0
# 0.012                           128.0                           255.0
# 0.018                           128.0                           255.0
# 0.024                           128.0                           255.0
# ...                               ...                             ...
# 2.982                           128.0                           255.0
# 2.988                           128.0                           255.0
# 2.994                           128.0                           255.0
# 3.000                           128.0                           255.0
# 3.000                           128.0                           255.0
#
#        boxBody2.frameTranslation.color[2]  boxBody2.frameTranslation.color[3]
# time
# 0.000                               128.0                               255.0
# 0.006                               128.0                               255.0
# 0.012                               128.0                               255.0
# 0.018                               128.0                               255.0
# 0.024                               128.0                               255.0
# ...                                   ...                                 ...
# 2.982                               128.0                               255.0
# 2.988                               128.0                               255.0
# 2.994                               128.0                               255.0
# 3.000                               128.0                               255.0
# 3.000                               128.0                               255.0
#
# [502 rows x 1186 columns]

# %%
data["boxBody1.R.T[1,1]"]
# Out:
# time
# 0.0    1.0
# 3.0    1.0
# Name: boxBody1.R.T[1,1], dtype: float64
